# %% [markdown]
# # Data Collection:

# %% [markdown]
# ## Web Page Scrapping:

# %%
import requests; # Making requests to our API
from bs4 import BeautifulSoup; # API for manipulating webcontent

import pandas as pd;
import json; # Parse jSON data


from selenium import webdriver;# Runs browser in headless mode ensuring any javascript is run
from selenium.webdriver.edge.webdriver import DesiredCapabilities;

# %% [raw]
# url = "https://fr.python-requests.org/en/latest/";
#
# # Make the API requests
# try :
#     response = requests.get(url);
#     response.close();
# except:
#     print("Resquest Error !");

# %% [raw]
# # Response data
# data = response.text;
# #Preparing the Soup
# soup = BeautifulSoup(data, "html5lib");
# data

# %%
# Create a Headless Chrome Driver
DRIVER_PATH = "C:/chromedriver_linux64";
driver = webdriver.Edge(executable_path="C:\edgedriver_win64\msedgedriver.exe", );

driver.get("http://localhost:8080/wordpress/");

# %%
soup = BeautifulSoup(driver.page_source);

# %%
soup.tagStack
# Out:
# [<html lang="en-US"><head>
#  <meta charset="utf-8"/>
#  <meta content="width=device-width, initial-scale=1, minimum-scale=1" name="viewport"/>
#  <link href="http://gmpg.org/xfn/11" rel="profile"/>
#  <title>Just another WordPress site</title>
#  <meta content="max-image-preview:large" name="robots"/>
#  <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
#  <link href="//s.w.org" rel="dns-prefetch"/>
#  <link href="http://localhost:8080/wordpress/feed/" rel="alternate" title=" » Feed" type="application/rss+xml"/>
#  <link href="http://localhost:8080/wordpress/comments/feed/" rel="alternate" title=" » Comments Feed" type="application/rss+xml"/>
#  <script type="text/javascript">
# ...
